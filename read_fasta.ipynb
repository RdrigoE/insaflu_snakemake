# %%
from Bio import SeqIO
for seq_record in SeqIO.parse("projects/2_project/main_result/consensus/ERR10039715__SARS_COV_2_consensus.fasta", "fasta"):
    print(seq_record.id)
    print((seq_record.seq[265:13468]))
# Out:
# ERR10039715__SARS_COV_2
# ...
